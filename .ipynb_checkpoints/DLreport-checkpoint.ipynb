# %% [markdown]
# Convulational Neural Network - 4 layers

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, classification_report, confusion_matrix
import tensorflow as tf
from PIL import Image
import os
from tensorflow.keras import layers, Sequential
from collections import Counter
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
import sklearn.metrics
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
#  Data Loading & Exploratory Data Analysis

# %%
dataset = r'/home/konnie/lungdb'
class_folders = ['Tumor', 'Normal']
target_size = (224, 224) 
valid_extensions = ('.jpg', '.jpeg', '.png')

images = []
labels = []

for class_idx, folder_name in enumerate(class_folders):
    class_path = os.path.join(dataset, folder_name)
    
   
    class_images = [
        os.path.join(class_path, fname)
        for fname in os.listdir(class_path)
        if fname.lower().endswith(valid_extensions)
    ]
  
    for img_path in class_images:
        try:
            with Image.open(img_path) as img:
                if img.mode != 'RGB':
                    img = img.convert('RGB')
                img_resized = img.resize(target_size)
                images.append(np.array(img_resized))
                labels.append(class_idx)
        except Exception as e:
            print(f"Error loading {img_path}: {str(e)}")


images_array = np.array(images)
labels_array = np.array(labels)

print(f"Images array shape: {images_array.shape}")  
print(f"Labels array shape: {labels_array.shape}")
# Out:
# Images array shape: (1097, 224, 224, 3)
# Labels array shape: (1097,)

# %% [markdown]
# Visualize the two Classes

# %%
class_names = ['Normal case', 'Tumor case']
valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff')

img_height, img_width = 224, 224
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset,
    labels='inferred',
    label_mode='int', 
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=42
)

class_names = train_ds.class_names
print("Class names:", class_names)


plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
plt.show()
# Out:
# Found 1097 files belonging to 2 classes.
# Class names: ['Normal', 'Tumor']
# 2025-06-01 13:31:15.709857: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-06-01 13:31:15.713838: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-01 13:31:15.727188: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2025-06-01 13:31:15.847924: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2025-06-01 13:31:15.850964: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 1796630000 Hz

# %% [markdown]
# Split Dataset into Train and Test

# %%
x_train, x_test, y_train, y_test = train_test_split(
    images_array, labels_array, test_size=0.2, random_state=42)

print("The data type of the images is:", x_train.dtype)
print("The shape of the train set:", x_train.shape)
print("The shape of the test set:", x_test.shape)
print("Number of training observations:", x_train.shape[0])
print("Number of testing observations:", x_test.shape[0])
print("Train label distribution:", Counter(y_train))
print("Test label distribution:", Counter(y_test))
# Out:
# The data type of the images is: uint8
# The shape of the train set: (877, 224, 224, 3)
# The shape of the test set: (220, 224, 224, 3)
# Number of training observations: 877
# Number of testing observations: 220
# Train label distribution: Counter({0: 543, 1: 334})
# Test label distribution: Counter({0: 138, 1: 82})

# %% [markdown]
# Data Preprocessing - Normalization

# %%
print(f"Value interval of the train set before the min-max normalization:[{x_train.min()},{x_train.max()}]")
print(f"Value interval of the test set before the min-max normalization:[{x_test.min()},{x_test.max()}]")
# scale the pixels to the [0,1] range
x_train = x_train / 255.0
x_test = x_test / 255.0
print(f"Value interval of the train set after the min-max normalization:[{x_train.min()},{x_train.max()}]")
print(f"Value interval of the test set after the min-max normalization:[{x_test.min()},{x_test.max()}]")
# Out:
# Value interval of the train set before the min-max normalization:[0,255]
# Value interval of the test set before the min-max normalization:[0,255]
# Value interval of the train set after the min-max normalization:[0.0,1.0]
# Value interval of the test set after the min-max normalization:[0.0,1.0]

# %% [markdown]
# CNN Overview

# %%
cnn_model = tf.keras.models.Sequential([
    tf.keras.Input(shape=(224, 224, 3)),         
                    
    layers.Conv2D(32, (3,3), padding="same", activation="relu"),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), padding="same", activation="relu"),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), padding="same", activation="relu"),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(256, (3,3), padding="same", activation="relu"),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dropout(0.5),
    layers.Dense(512, activation="relu"),
    layers.Dense(2, activation="softmax")  # For 2 classes: Normal and Tumor
])

cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               25690624
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 26,080,066
# Trainable params: 26,080,066
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Data Augmentation using ImageDataGenerator

# %%
data_augmentation = ImageDataGenerator(
    rotation_range=15,      
    width_shift_range=0.1,  
    height_shift_range=0.1, 
    horizontal_flip=True,   
    zoom_range=0.1,         
    fill_mode='nearest',    
    validation_split=0.2    
)

# %% [markdown]
# Compile the model without augmentation

# %%
cnn_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# Train and Validation Generator

# %%
# Generate training and validation flows
train_generator = data_augmentation.flow(
    x_train, y_train,
    batch_size=32,
    subset='training'
)

validation_generator = data_augmentation.flow(
    x_train, y_train, 
    batch_size=32,
    subset='validation',
    shuffle=False  # Don't shuffle validation data
)

# %% [markdown]
# Fitting the model

# %%
# Modified fit method to use generators
history_1 = cnn_model.fit(
    train_generator,
    steps_per_epoch=len(x_train) * 0.8 // 32,  # 80% of data is used for training with validation_split=0.2
    epochs=10,
    validation_data=validation_generator,
    validation_steps=len(x_train) * 0.2 // 32,  # 20% of data is used for validation
)
# Out:
# Epoch 1/10
# 21/21 [==============================] - 27s 1s/step - loss: 1.3983 - accuracy: 0.5430 - val_loss: 0.6346 - val_accuracy: 0.7063
# Epoch 2/10
# 21/21 [==============================] - 23s 1s/step - loss: 0.6527 - accuracy: 0.6394 - val_loss: 0.6547 - val_accuracy: 0.6250
# Epoch 3/10
# 21/21 [==============================] - 22s 1s/step - loss: 0.6534 - accuracy: 0.6299 - val_loss: 0.6302 - val_accuracy: 0.5750
# Epoch 4/10
# 21/21 [==============================] - 23s 1s/step - loss: 0.6344 - accuracy: 0.5927 - val_loss: 0.5606 - val_accuracy: 0.6938
# Epoch 5/10
# 21/21 [==============================] - 23s 1s/step - loss: 0.5999 - accuracy: 0.6588 - val_loss: 0.5623 - val_accuracy: 0.6562
# Epoch 6/10
# 21/21 [==============================] - 24s 1s/step - loss: 0.6063 - accuracy: 0.6150 - val_loss: 0.5668 - val_accuracy: 0.6375
# Epoch 7/10
# 21/21 [==============================] - 24s 1s/step - loss: 0.6056 - accuracy: 0.6222 - val_loss: 0.5511 - val_accuracy: 0.6938
# Epoch 8/10
# 21/21 [==============================] - 24s 1s/step - loss: 0.5948 - accuracy: 0.6635 - val_loss: 0.5289 - val_accuracy: 0.6938
# Epoch 9/10
# 21/21 [==============================] - 24s 1s/step - loss: 0.5806 - accuracy: 0.6592 - val_loss: 0.5539 - val_accuracy: 0.6938
# Epoch 10/10
# 21/21 [==============================] - 24s 1s/step - loss: 0.5861 - accuracy: 0.6846 - val_loss: 0.5016 - val_accuracy: 0.7000

# %% [markdown]
# Accuracy and Loss plots

# %%
def plot_training_history(history, title):
    """Plot the training and validation accuracy/loss"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    # Accuracy
    ax1.plot(history.history['accuracy'])
    ax1.plot(history.history['val_accuracy'])
    ax1.set_title(f'{title} - Accuracy')
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.legend(['Train', 'Validation'], loc='lower right')
    
    # Loss
    ax2.plot(history.history['loss'])
    ax2.plot(history.history['val_loss'])
    ax2.set_title(f'{title} - Loss')
    ax2.set_ylabel('Loss')
    ax2.set_xlabel('Epoch')
    ax2.legend(['Train', 'Validation'], loc='upper right')
    
    plt.tight_layout()
    plt.show()

plot_training_history(history_1, "Simple CNN")

predictions_nn_probs = cnn_model.predict(x_test)
predictions_nn = np.argmax(predictions_nn_probs, axis=1)
test_accuracy_nn = sklearn.metrics.accuracy_score(y_test, predictions_nn)

print("The Accuracy of the Neural Network on the Test Data is", test_accuracy_nn)
# Out:
# The Accuracy of the Neural Network on the Test Data is 0.8272727272727273

# %%
history_2 = cnn_model.fit(
    train_generator,
    steps_per_epoch=len(x_train) * 0.8 // 64,
    epochs=30,
    validation_data=validation_generator,
    validation_steps=len(x_train) * 0.2 // 64,
)
# Out:
# Epoch 1/30
# 10/10 [==============================] - 19s 2s/step - loss: 0.5627 - accuracy: 0.6844 - val_loss: 0.4374 - val_accuracy: 0.8125
# Epoch 2/30
# 10/10 [==============================] - 17s 2s/step - loss: 0.5368 - accuracy: 0.7281 - val_loss: 0.5075 - val_accuracy: 0.7031
# Epoch 3/30
# 10/10 [==============================] - 20s 2s/step - loss: 0.5497 - accuracy: 0.7000 - val_loss: 0.3792 - val_accuracy: 0.8750
# Epoch 4/30
# 10/10 [==============================] - 19s 2s/step - loss: 0.5165 - accuracy: 0.7250 - val_loss: 0.4082 - val_accuracy: 0.8125
# Epoch 5/30
# 10/10 [==============================] - 17s 2s/step - loss: 0.5104 - accuracy: 0.7673 - val_loss: 0.4049 - val_accuracy: 0.8594
# Epoch 6/30
# 10/10 [==============================] - 17s 2s/step - loss: 0.5247 - accuracy: 0.7138 - val_loss: 0.4095 - val_accuracy: 0.8281
# Epoch 7/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.5174 - accuracy: 0.7327 - val_loss: 0.4017 - val_accuracy: 0.7969
# Epoch 8/30
# 10/10 [==============================] - 20s 2s/step - loss: 0.5035 - accuracy: 0.7516 - val_loss: 0.4644 - val_accuracy: 0.7812
# Epoch 9/30
# 10/10 [==============================] - 19s 2s/step - loss: 0.5035 - accuracy: 0.7406 - val_loss: 0.4118 - val_accuracy: 0.8125
# Epoch 10/30
# 10/10 [==============================] - 21s 2s/step - loss: 0.5129 - accuracy: 0.7531 - val_loss: 0.4301 - val_accuracy: 0.8125
# Epoch 11/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.4968 - accuracy: 0.7375 - val_loss: 0.4316 - val_accuracy: 0.8125
# Epoch 12/30
# 10/10 [==============================] - 19s 2s/step - loss: 0.4704 - accuracy: 0.7875 - val_loss: 0.3885 - val_accuracy: 0.8594
# Epoch 13/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.4783 - accuracy: 0.7688 - val_loss: 0.3396 - val_accuracy: 0.8750
# Epoch 14/30
# 10/10 [==============================] - 23s 2s/step - loss: 0.4657 - accuracy: 0.7781 - val_loss: 0.3884 - val_accuracy: 0.8125
# Epoch 15/30
# 10/10 [==============================] - 20s 2s/step - loss: 0.4674 - accuracy: 0.7579 - val_loss: 0.3783 - val_accuracy: 0.8750
# Epoch 16/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.4473 - accuracy: 0.7956 - val_loss: 0.3132 - val_accuracy: 0.8906
# Epoch 17/30
# 10/10 [==============================] - 19s 2s/step - loss: 0.4652 - accuracy: 0.7547 - val_loss: 0.3937 - val_accuracy: 0.8281
# Epoch 18/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.4759 - accuracy: 0.7642 - val_loss: 0.4627 - val_accuracy: 0.7344
# Epoch 19/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.5181 - accuracy: 0.7201 - val_loss: 0.4491 - val_accuracy: 0.7500
# Epoch 20/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.4335 - accuracy: 0.8094 - val_loss: 0.4515 - val_accuracy: 0.7656
# Epoch 21/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.5006 - accuracy: 0.7531 - val_loss: 0.3917 - val_accuracy: 0.8125
# Epoch 22/30
# 10/10 [==============================] - 19s 2s/step - loss: 0.4873 - accuracy: 0.7484 - val_loss: 0.3981 - val_accuracy: 0.8281
# Epoch 23/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.4729 - accuracy: 0.7563 - val_loss: 0.5428 - val_accuracy: 0.6562
# Epoch 24/30
# 10/10 [==============================] - 19s 2s/step - loss: 0.5359 - accuracy: 0.6981 - val_loss: 0.3671 - val_accuracy: 0.8906
# Epoch 25/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.4528 - accuracy: 0.7781 - val_loss: 0.3270 - val_accuracy: 0.8750
# Epoch 26/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.4699 - accuracy: 0.7610 - val_loss: 0.3234 - val_accuracy: 0.8125
# Epoch 27/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.4596 - accuracy: 0.7987 - val_loss: 0.3212 - val_accuracy: 0.8750
# Epoch 28/30
# 10/10 [==============================] - 17s 2s/step - loss: 0.4255 - accuracy: 0.8062 - val_loss: 0.2758 - val_accuracy: 0.9062
# Epoch 29/30
# 10/10 [==============================] - 18s 2s/step - loss: 0.4331 - accuracy: 0.7830 - val_loss: 0.3393 - val_accuracy: 0.8438
# Epoch 30/30
# 10/10 [==============================] - 19s 2s/step - loss: 0.4704 - accuracy: 0.7830 - val_loss: 0.3329 - val_accuracy: 0.9062

# %%
plot_training_history(history_2, "Simple CNN")

predictions_nn_probs_2 = cnn_model.predict(x_test)
predictions_nn_2 = np.argmax(predictions_nn_probs_2, axis=1)
test_accuracy_nn2 = sklearn.metrics.accuracy_score(y_test, predictions_nn_2)

print("The Accuracy of the Neural Network on the Test Data is", test_accuracy_nn2)
# Out:
# The Accuracy of the Neural Network on the Test Data is 0.8272727272727273

# %%
history_2 = cnn_model.fit(
    train_generator,
    steps_per_epoch=len(x_train) * 0.8 // 64,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(x_train) * 0.2 // 64,
)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.4195 - accuracy: 0.7906 - val_loss: 0.3217 - val_accuracy: 0.8750
# Epoch 2/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4260 - accuracy: 0.8062 - val_loss: 0.3221 - val_accuracy: 0.8594
# Epoch 3/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4089 - accuracy: 0.8156 - val_loss: 0.3969 - val_accuracy: 0.7969
# Epoch 4/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.4962 - accuracy: 0.7421 - val_loss: 0.3241 - val_accuracy: 0.8438
# Epoch 5/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4379 - accuracy: 0.7625 - val_loss: 0.2975 - val_accuracy: 0.8906
# Epoch 6/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4281 - accuracy: 0.7812 - val_loss: 0.3512 - val_accuracy: 0.8594
# Epoch 7/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.4407 - accuracy: 0.8031 - val_loss: 0.2978 - val_accuracy: 0.8906
# Epoch 8/50
# 10/10 [==============================] - 13s 1s/step - loss: 0.4300 - accuracy: 0.7987 - val_loss: 0.3347 - val_accuracy: 0.9062
# Epoch 9/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.4431 - accuracy: 0.7736 - val_loss: 0.3640 - val_accuracy: 0.7969
# Epoch 10/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4263 - accuracy: 0.8031 - val_loss: 0.3420 - val_accuracy: 0.8438
# Epoch 11/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4136 - accuracy: 0.8219 - val_loss: 0.3717 - val_accuracy: 0.8438
# Epoch 12/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.4261 - accuracy: 0.8019 - val_loss: 0.3515 - val_accuracy: 0.8594
# Epoch 13/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4343 - accuracy: 0.7812 - val_loss: 0.3678 - val_accuracy: 0.8594
# Epoch 14/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4743 - accuracy: 0.7799 - val_loss: 0.3336 - val_accuracy: 0.9062
# Epoch 15/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4040 - accuracy: 0.8250 - val_loss: 0.3235 - val_accuracy: 0.8750
# Epoch 16/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4192 - accuracy: 0.8031 - val_loss: 0.3181 - val_accuracy: 0.9062
# Epoch 17/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4403 - accuracy: 0.8062 - val_loss: 0.2771 - val_accuracy: 0.9219
# Epoch 18/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3669 - accuracy: 0.8302 - val_loss: 0.2514 - val_accuracy: 0.9375
# Epoch 19/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.4393 - accuracy: 0.7906 - val_loss: 0.2729 - val_accuracy: 0.8594
# Epoch 20/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4038 - accuracy: 0.8019 - val_loss: 0.2825 - val_accuracy: 0.9062
# Epoch 21/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4261 - accuracy: 0.7987 - val_loss: 0.2838 - val_accuracy: 0.9062
# Epoch 22/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3921 - accuracy: 0.8313 - val_loss: 0.3695 - val_accuracy: 0.8281
# Epoch 23/50
# 10/10 [==============================] - 17s 2s/step - loss: 0.4616 - accuracy: 0.7750 - val_loss: 0.3600 - val_accuracy: 0.8438
# Epoch 24/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3965 - accuracy: 0.7987 - val_loss: 0.2682 - val_accuracy: 0.9531
# Epoch 25/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4614 - accuracy: 0.7875 - val_loss: 0.3363 - val_accuracy: 0.9375
# Epoch 26/50
# 10/10 [==============================] - 18s 2s/step - loss: 0.3683 - accuracy: 0.8469 - val_loss: 0.2532 - val_accuracy: 0.9219
# Epoch 27/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.4072 - accuracy: 0.8031 - val_loss: 0.4050 - val_accuracy: 0.8594
# Epoch 28/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3663 - accuracy: 0.8562 - val_loss: 0.2546 - val_accuracy: 0.8906
# Epoch 29/50
# 10/10 [==============================] - 18s 2s/step - loss: 0.3628 - accuracy: 0.8302 - val_loss: 0.2718 - val_accuracy: 0.9219
# Epoch 30/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3634 - accuracy: 0.8656 - val_loss: 0.2491 - val_accuracy: 0.9062
# Epoch 31/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.3970 - accuracy: 0.8281 - val_loss: 0.2999 - val_accuracy: 0.8750
# Epoch 32/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.3682 - accuracy: 0.8333 - val_loss: 0.3172 - val_accuracy: 0.8594
# Epoch 33/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3877 - accuracy: 0.8333 - val_loss: 0.3313 - val_accuracy: 0.8594
# Epoch 34/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.3600 - accuracy: 0.8469 - val_loss: 0.2500 - val_accuracy: 0.8906
# Epoch 35/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3661 - accuracy: 0.8344 - val_loss: 0.2753 - val_accuracy: 0.8594
# Epoch 36/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.4149 - accuracy: 0.8094 - val_loss: 0.2634 - val_accuracy: 0.8906
# Epoch 37/50
# 10/10 [==============================] - 13s 1s/step - loss: 0.3288 - accuracy: 0.8844 - val_loss: 0.3430 - val_accuracy: 0.8594
# Epoch 38/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3926 - accuracy: 0.8000 - val_loss: 0.3099 - val_accuracy: 0.8594
# Epoch 39/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3855 - accuracy: 0.8344 - val_loss: 0.2160 - val_accuracy: 0.9219
# Epoch 40/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3444 - accuracy: 0.8239 - val_loss: 0.2294 - val_accuracy: 0.9062
# Epoch 41/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3591 - accuracy: 0.8188 - val_loss: 0.1930 - val_accuracy: 0.9531
# Epoch 42/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3770 - accuracy: 0.8281 - val_loss: 0.2644 - val_accuracy: 0.8906
# Epoch 43/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3794 - accuracy: 0.8270 - val_loss: 0.2269 - val_accuracy: 0.9219
# Epoch 44/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.3339 - accuracy: 0.8711 - val_loss: 0.3174 - val_accuracy: 0.8594
# Epoch 45/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.3533 - accuracy: 0.8459 - val_loss: 0.2077 - val_accuracy: 0.9688
# Epoch 46/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.3425 - accuracy: 0.8333 - val_loss: 0.2182 - val_accuracy: 0.8906
# Epoch 47/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3906 - accuracy: 0.8396 - val_loss: 0.2829 - val_accuracy: 0.9062
# Epoch 48/50
# 10/10 [==============================] - 12s 1s/step - loss: 0.3528 - accuracy: 0.8375 - val_loss: 0.2445 - val_accuracy: 0.9375
# Epoch 49/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3350 - accuracy: 0.8396 - val_loss: 0.2066 - val_accuracy: 0.9219
# Epoch 50/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.3956 - accuracy: 0.8396 - val_loss: 0.2100 - val_accuracy: 0.9062

# %%
plot_training_history(history_2, "Simple CNN")

predictions_nn_probs_2 = cnn_model.predict(x_test)
predictions_nn_2 = np.argmax(predictions_nn_probs_2, axis=1)
test_accuracy_nn2 = sklearn.metrics.accuracy_score(y_test, predictions_nn_2)

print("The Accuracy of the Neural Network on the Test Data is", test_accuracy_nn2)
# Out:
# The Accuracy of the Neural Network on the Test Data is 0.8545454545454545
